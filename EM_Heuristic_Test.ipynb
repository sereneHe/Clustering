# %% [markdown]
# # NCPOP

# %%
class NCPOLR(object):
    """Estimator based on NCPOP Regressor

    References
    ----------
    Quan Zhou https://github.com/Quan-Zhou/Proper-Learning-of-LDS/blob/master/ncpop/functions.py
    
    Examples
    --------
    """
    
    def __init__(self, **kwargs):
        super(NCPOLR, self).__init__()
    
    
    def generate_multioperators(self, name, n_vars, m_vars, hermitian=None, commutative=False):
        """Generates a number of commutative or noncommutative operators

        :param name: The prefix in the symbolic representation of the noncommuting
                     variables. This will be suffixed by a number from 0 to
                     n_vars-1 if n_vars > 1.
        :type name: str.
        :param n_vars: The number of variables.
        :type n_vars: int.
        :param hermitian: Optional parameter to request Hermitian variables .
        :type hermitian: bool.
        :param commutative: Optional parameter to request commutative variables.
                            Commutative variables are Hermitian by default.
        :type commutative: bool.

        :returns: list of :class:`sympy.physics.quantum.operator.Operator` or
                  :class:`sympy.physics.quantum.operator.HermitianOperator`
                  variables

        :Example:

        >>> generate_variables('y', 2, commutative=True)
        #[y0, y1]
        """

        variables = []
        variables1 = []
        variables2 = []
        for i in range(n_vars):
            if n_vars > 1:
                var_name1 = '%s%s' % (name, i)
            else:
                var_name1 = '%s' % name
            if hermitian is not None and hermitian:
                variables1.append(HermitianOperator(var_name1))
            else:
                variables1.append(Operator(var_name1))
            variables1[-1].is_commutative = commutative
        for n in range(len(variables1)):        
            for j in range(m_vars):
                if m_vars > 1:
                    var_name = '%s%s' % (variables1[n], j)
                else:
                    var_name = '%s' % variables1[n]
                if hermitian is not None and hermitian:
                    variables2.append(HermitianOperator(var_name))
                else:
                    variables2.append(Operator(var_name))
                variables2[-1].is_commutative = commutative
        var = np.matrix(np.array(variables2).reshape(n_vars,m_vars))
        var = np.array(variables2).reshape(n_vars,m_vars)
        #print(variables1,variables2)
        return var

        
    def estimate(self, Y, m,level):
        """Fit Estimator based on NCPOP Regressor model and predict y or produce residuals.
        The module converts a noncommutative optimization problem provided in SymPy
        format to an SDPA semidefinite programming problem.
        Define a function for solving the NCPO problems with 
        given standard deviations of process noise and observtion noise,
        length of  estimation data and required relaxation level. 

        Parameters
        ----------
        Y: array
            Variable seen as input
        m:
        n:

        Returns
        -------
        y_predict: array
            regression predict values of y or residuals
        obj: num
            Objective value in optima
        """
        n=7
        T= len(Y)
        Y = np.transpose(Y)
        # Decision Variables
        G = NCPOLR().generate_multioperators("G", n_vars=n, m_vars=n, hermitian=True, commutative=False)
        Fdash = NCPOLR().generate_multioperators("Fdash", n_vars=m, m_vars=n, hermitian=True, commutative=False)
        phi = NCPOLR().generate_multioperators("phi", n_vars=n, m_vars=T+1, hermitian=True, commutative=False)
        q = NCPOLR().generate_multioperators("q", n_vars=n, m_vars=T, hermitian=True, commutative=False)
        p = NCPOLR().generate_multioperators("p", n_vars=m, m_vars=T, hermitian=True, commutative=False)
        f = NCPOLR().generate_multioperators("f", n_vars=m, m_vars=T, hermitian=True, commutative=False)
        

        # Objective
        #obj = sum((Y[i]-f[i])**2 for i in range(T)) + 0.0005*sum(p[i]**2 for i in range(T)) + 0.0001*sum(q[i]**2 for i in range(T))
        obj = sum((Y[mm][i])*2 for i in range(T) for mm in range(m))+ 0.0005*sum(p[mm][i]*2 for i in range(T) for mm in range(m)) + 0.0001*sum(q[nn][i]*2 for i in range(T) for nn in range(n)) 
        
        # Constraints
        
        ine1 = [f[mm][i] - Fdash[mm][nn]*phi[nn][i+1] - p[mm][i] for nn in range(n) for i in range(T) for mm in range(m)]
        ine2 = [-f[mm][i] + Fdash[mm][nn]*phi[nn][i+1] + p[mm][i] for nn in range(n) for i in range(T) for mm in range(m)]
        ine3 = [phi[nn][i+1] - G[nn][nn]*phi[nn][i] - q[nn][i] for nn in range(n) for i in range(T)]
        ine4 = [-phi[nn][i+1] + G[nn][nn]*phi[nn][i] + q[nn][i] for i in range(T) for nn in range(n)]
        #ine5 = [(Y[i]-f[i])**2 for i in range(T)]
        ines = ine1+ine2+ine3+ine4 

        # Solve the NCPO
        GG = Operator(np.asarray(G).reshape(-1))
        FFdash = Operator(np.asarray(Fdash).reshape(-1))
        f = Operator(np.asarray(f).reshape(-1))
        q = Operator(np.asarray(q).reshape(-1))
        p = Operator(np.asarray(p).reshape(-1))
        phi = Operator(np.asarray(phi).reshape(-1))
        #print([Operator(GG),Operator(FFdash),Operator(f),Operator(p),Operator(phi),Operator(q)])
    
        sdp = SdpRelaxation(variables = flatten([GG,FFdash,f,p,phi,q]),verbose = 1)
        sdp.get_relaxation(level, objective=obj, inequalities=ines)
        sdp.solve(solver='mosek')
        '''
        Attributes:
          - `monomial_sets`: The monomial sets that generate the moment matrix blocks.

          - `monomial_index`: Dictionary that maps monomials to SDP variables.

          - `constraints`: The complete set of constraints after preprocesssing.

          - `primal`: The primal optimal value.

          - `dual`: The dual optimal value.

          - `x_mat`: The primal solution matrix.

          - `y_mat`: The dual solution matrix.

          - `solution_time`: The amount of time taken to solve the relaxation.

          - `status`: The solution status of the relaxation.
        '''
        sdp.write_to_file("slutions.csv")
        sdp.write_to_file('example.dat-s')
        sdp.find_solution_ranks()
        sdp.ave = np.average(Y, axis=0)  
        #sdp.solve(solver='sdpa', solverparameters={"executable":"sdpa_gmp","executable": "C:/Users/zhouq/Documents/sdpa7-windows/sdpa.exe"})
        print(sdp.primal, sdp.dual,sdp.status)
        return sdp.primal,sdp.ave
        '''
        if(sdp.status != 'infeasible'):
            print('ok.')
            f_pred = []
            p_pred = []
            phi_pred = []
            q_pred = []
            for t in range(len(np.asarray(p).reshape(-1))):
                f_pred.append(sdp[f[t]])
                p_pred.append(sdp[p[t]])
            for t in range(len(np.asarray(q).reshape(-1))):
                phi_pred.append(sdp[phi[t]])
                q_pred.append(sdp[q[t]])
            Para = [sdp[GG].reshape(n,n),sdp[FFdash].reshape(m,n)]
            return f_pred.reshape(m,T),p_pred.reshape(m,T),phi_pred.reshape(n,T),p_pred.reshape(n,T),Para
            '''

# %% [markdown]
# # Test_EM_Heuristic

# %%
import pandas as pd
from itertools import product
import sys
sys.path.append("/home/zhouqua1") 
sys.path.append("/home/zhouqua1/NCPOP") 
from inputlds import*
from functions import*
from ncpol2sdpa import*
import numpy as np
from math import sqrt
from sympy.physics.quantum import HermitianOperator, Operator


L = [1,0,1,0,0,0] 
level = 1
Rawdata = pd.read_csv('HeartRate_MIT_Test.csv',sep=',',header='infer',nrows=11)
X = pd.DataFrame(Rawdata.drop('Time',axis=1))
m= len(np.transpose(X))
print(X)
level = 1
X_Group0 = X.iloc[:,np.flatnonzero(L)]
X_Group0 = np.array(X_Group0)#.reshape(-1)
N0 = len(np.transpose(X_Group0))

X_Group1 = X.iloc[:,np.flatnonzero(list(abs(np.asarray(L) -1)))]
X_Group1 = np.array(X_Group1)#.reshape(-1)
N1 = len(np.transpose(X_Group1))
print(N0,N1)
primal_value = NCPOLR().estimate(X_Group0,N0,level)[0]+ NCPOLR().estimate(X_Group1,N1,level)[0]

#y_LDS2_predict = NCPOLR().estimate(list(y_LDS2),level)
print(print(L,primal_value))

# itaration
l = [0,1]
prod = list(product(l, repeat=m))

for ll in range(len(prod)):
    L_new= np.array(prod[ll])
    if len([i for i in L_new if i==1]) >1 and len([i for i in L_new if i==0]) >1:
        #Separate into K=2 groups
        X_Group00 = X.iloc[:,np.flatnonzero(L_new)]
        X_Group00 = np.array(X_Group00)#.reshape(-1)
        N00 = len(np.transpose(X_Group00))

        X_Group11 = X.iloc[:,np.flatnonzero(list(abs(np.asarray(L_new) -1)))]
        X_Group11 = np.array(X_Group11)#.reshape(-1)
        N11 = len(np.transpose(X_Group11))
        print(X_Group00,X_Group11)

        primal_value_new = NCPOLR().estimate(X_Group00,N00,level)[0]+ NCPOLR().estimate(X_Group11,N11,level)[0]
        print(L_new,primal_value_new)
        if primal_value_new < primal_value:
            L= L_new
            primal_value = primal_value_new 
            print(L,primal_value)
        else:
            continue
    else:
        continue
print(L)
labels_pred = L
# Out:
#     Health_1  Health_2  Health_3  Disease_1  Disease_2  Disease_3
# 0    84.2697   86.0997   92.7832    91.4634    101.957    88.6520
# 1    84.2697   85.1549   92.7607    91.4634    102.651    89.9465
# 2    84.0619   84.7458   93.4589    91.1834    102.552    89.0909
# 3    85.6542   84.6010   93.3333    91.8788    102.329    90.0317
# 4    87.2093   84.4511   92.0536    91.1772    102.516    90.3430
# 5    87.1246   84.8366   90.3252    89.7992    102.740    90.3987
# 6    86.8726   84.4924   90.4617    90.3571    102.740    91.1116
# 7    86.7052   83.5455   91.4634    92.0227    102.146    91.1382
# 8    87.5899   83.3333   90.9669    91.9105    101.683    91.8114
# 9    89.1475   83.9661   89.7903    91.1410    102.101    91.9394
# 10   89.8204   84.9048   88.4148    91.9571    102.114    91.4815
# 2 4
# The problem has 6 noncommuting Hermitian variables
# Calculating block structure...
# Estimated number of SDP variables: 90
# Generating moment matrix...
# Reduced number of SDP variables: 90 90 (done: 101.11%, ETA 00:00:-0.0)
# Processing 169/462 constraints...
# Warning: The objective function has a non-zero 3917.0739999999996 constant term. It is not included in the SDP objective.
# Processing 462/462 constraints...
# Problem
#   Name                   :
#   Objective sense        : minimize
#   Type                   : CONIC (conic optimization problem)
#   Constraints            : 90
#   Affine conic cons.     : 0
#   Disjunctive cons.      : 0
#   Cones                  : 0
#   Scalar variables       : 0
#   Matrix variables       : 1 (scalarized: 113050)
#   Integer variables      : 0
#
# Optimizer started.
# Presolve started.
# Linear dependency checker started.
# Linear dependency checker terminated.
# Eliminator started.
# Freed constraints in eliminator : 0
# Eliminator terminated.
# Eliminator - tries                  : 1                 time                   : 0.00
# Lin. dep.  - tries                  : 1                 time                   : 0.00
# Lin. dep.  - primal attempts        : 1                 successes              : 1
# Lin. dep.  - dual attempts          : 0                 successes              : 0
# Lin. dep.  - primal deps.           : 0                 dual deps.             : 0
# Presolve terminated. Time: 0.00
# Optimizer  - threads                : 8
# Optimizer  - solved problem         : the primal
# Optimizer  - Constraints            : 90
# Optimizer  - Cones                  : 0
# Optimizer  - Scalar variables       : 0                 conic                  : 0
# Optimizer  - Semi-definite variables: 1                 scalarized             : 113050
# Factor     - setup time             : 0.00
# Factor     - dense det. time        : 0.00              GP order time          : 0.00
# Factor     - nonzeros before factor : 4095              after factor           : 4095
# Factor     - dense dim.             : 0                 flops                  : 3.60e+05
# ITE PFEAS    DFEAS    GFEAS    PRSTATUS   POBJ              DOBJ              MU       TIME
# 0   1.0e+00  1.0e+00  2.0e+00  0.00e+00   1.000000000e+00   0.000000000e+00   1.0e+00  0.03
# 1   0.0e+00  0.0e+00  0.0e+00  1.00e+00   0.000000000e+00   0.000000000e+00   0.0e+00  0.07
# Optimizer terminated. Time: 0.07
#
# 3917.0739999999996 3917.0739999999996 optimal
# The problem has 6 noncommuting Hermitian variables
# Calculating block structure...
# Estimated number of SDP variables: 90
# Generating moment matrix...
# Reduced number of SDP variables: 90 90 (done: 101.11%, ETA 00:00:-0.0)
# Processing 121/770 constraints...
# Warning: The objective function has a non-zero 8111.917800000002 constant term. It is not included in the SDP objective.
# Processing 770/770 constraints...
# Problem
#   Name                   :
#   Objective sense        : minimize
#   Type                   : CONIC (conic optimization problem)
#   Constraints            : 90
#   Affine conic cons.     : 0
#   Disjunctive cons.      : 0
#   Cones                  : 0
#   Scalar variables       : 0
#   Matrix variables       : 1 (scalarized: 306936)
#   Integer variables      : 0
#
# Optimizer started.
# Presolve started.
# Linear dependency checker started.
# Linear dependency checker terminated.
# Eliminator started.
# Freed constraints in eliminator : 0
# Eliminator terminated.
# Eliminator - tries                  : 1                 time                   : 0.00
# Lin. dep.  - tries                  : 1                 time                   : 0.00
# Lin. dep.  - primal attempts        : 1                 successes              : 1
# Lin. dep.  - dual attempts          : 0                 successes              : 0
# Lin. dep.  - primal deps.           : 0                 dual deps.             : 0
# Presolve terminated. Time: 0.00
# Optimizer  - threads                : 8
# Optimizer  - solved problem         : the primal
# Optimizer  - Constraints            : 90
# Optimizer  - Cones                  : 0
# Optimizer  - Scalar variables       : 0                 conic                  : 0
# Optimizer  - Semi-definite variables: 1                 scalarized             : 306936
# Factor     - setup time             : 0.00
# Factor     - dense det. time        : 0.00              GP order time          : 0.00
# Factor     - nonzeros before factor : 4095              after factor           : 4095
# Factor     - dense dim.             : 0                 flops                  : 4.16e+05
# ITE PFEAS    DFEAS    GFEAS    PRSTATUS   POBJ              DOBJ              MU       TIME
# 0   1.0e+00  1.0e+00  2.0e+00  0.00e+00   1.000000000e+00   0.000000000e+00   1.0e+00  0.08
# 1   0.0e+00  0.0e+00  0.0e+00  1.00e+00   0.000000000e+00   0.000000000e+00   0.0e+00  0.19
# Optimizer terminated. Time: 0.19
#
# 8111.917800000002 8111.917800000002 optimal
# [1, 0, 1, 0, 0, 0] 12028.991800000002
# None
# [[101.957   88.652 ]
#  [102.651   89.9465]
#  [102.552   89.0909]
#  [102.329   90.0317]
#  [102.516   90.343 ]
#  [102.74    90.3987]
#  [102.74    91.1116]
#  [102.146   91.1382]
#  [101.683   91.8114]
#  [102.101   91.9394]
#  [102.114   91.4815]] [[84.2697 86.0997 92.7832 91.4634]
#  [84.2697 85.1549 92.7607 91.4634]
#  [84.0619 84.7458 93.4589 91.1834]
#  [85.6542 84.601  93.3333 91.8788]
#  [87.2093 84.4511 92.0536 91.1772]
#  [87.1246 84.8366 90.3252 89.7992]
#  [86.8726 84.4924 90.4617 90.3571]
#  [86.7052 83.5455 91.4634 92.0227]
#  [87.5899 83.3333 90.9669 91.9105]
#  [89.1475 83.9661 89.7903 91.141 ]
#  [89.8204 84.9048 88.4148 91.9571]]
# The problem has 6 noncommuting Hermitian variables
# Calculating block structure...
# Estimated number of SDP variables: 90
# Generating moment matrix...
# Reduced number of SDP variables: 90 90 (done: 101.11%, ETA 00:00:-0.0)
# Processing 176/462 constraints...
# Warning: The objective function has a non-zero 4242.9478 constant term. It is not included in the SDP objective.
# Processing 462/462 constraints...
# Problem
#   Name                   :
#   Objective sense        : minimize
#   Type                   : CONIC (conic optimization problem)
#   Constraints            : 90
#   Affine conic cons.     : 0
#   Disjunctive cons.      : 0
#   Cones                  : 0
#   Scalar variables       : 0
#   Matrix variables       : 1 (scalarized: 113050)
#   Integer variables      : 0
#
# Optimizer started.
# Presolve started.
# Linear dependency checker started.
# Linear dependency checker terminated.
# Eliminator started.
# Freed constraints in eliminator : 0
# Eliminator terminated.
# Eliminator - tries                  : 1                 time                   : 0.00
# Lin. dep.  - tries                  : 1                 time                   : 0.00
# Lin. dep.  - primal attempts        : 1                 successes              : 1
# Lin. dep.  - dual attempts          : 0                 successes              : 0
# Lin. dep.  - primal deps.           : 0                 dual deps.             : 0
# Presolve terminated. Time: 0.00
# Optimizer  - threads                : 8
# Optimizer  - solved problem         : the primal
# Optimizer  - Constraints            : 90
# Optimizer  - Cones                  : 0
# Optimizer  - Scalar variables       : 0                 conic                  : 0
# Optimizer  - Semi-definite variables: 1                 scalarized             : 113050
# Factor     - setup time             : 0.00
# Factor     - dense det. time        : 0.00              GP order time          : 0.00
# Factor     - nonzeros before factor : 4095              after factor           : 4095
# Factor     - dense dim.             : 0                 flops                  : 3.60e+05
# ITE PFEAS    DFEAS    GFEAS    PRSTATUS   POBJ              DOBJ              MU       TIME
# 0   1.0e+00  1.0e+00  2.0e+00  0.00e+00   1.000000000e+00   0.000000000e+00   1.0e+00  0.03
# 1   0.0e+00  0.0e+00  0.0e+00  1.00e+00   0.000000000e+00   0.000000000e+00   0.0e+00  0.06
# Optimizer terminated. Time: 0.06
#
# 4242.9478 4242.9478 optimal
# The problem has 6 noncommuting Hermitian variables
# Calculating block structure...
# Estimated number of SDP variables: 90
# Generating moment matrix...
# Reduced number of SDP variables: 90 90 (done: 101.11%, ETA 00:00:-0.0)
# Processing 119/770 constraints...
# Warning: The objective function has a non-zero 7786.044000000001 constant term. It is not included in the SDP objective.
# Processing 770/770 constraints...
# Problem
#   Name                   :
#   Objective sense        : minimize
#   Type                   : CONIC (conic optimization problem)
#   Constraints            : 90
#   Affine conic cons.     : 0
#   Disjunctive cons.      : 0
#   Cones                  : 0
#   Scalar variables       : 0
#   Matrix variables       : 1 (scalarized: 306936)
#   Integer variables      : 0
#
# Optimizer started.
# Presolve started.
# Linear dependency checker started.
# Linear dependency checker terminated.
# Eliminator started.
# Freed constraints in eliminator : 0
# Eliminator terminated.
# Eliminator - tries                  : 1                 time                   : 0.00
# Lin. dep.  - tries                  : 1                 time                   : 0.00
# Lin. dep.  - primal attempts        : 1                 successes              : 1
# Lin. dep.  - dual attempts          : 0                 successes              : 0
# Lin. dep.  - primal deps.           : 0                 dual deps.             : 0
# Presolve terminated. Time: 0.00
# Optimizer  - threads                : 8
# Optimizer  - solved problem         : the primal
# Optimizer  - Constraints            : 90
# Optimizer  - Cones                  : 0
# Optimizer  - Scalar variables       : 0                 conic                  : 0
# Optimizer  - Semi-definite variables: 1                 scalarized             : 306936
# Factor     - setup time             : 0.00
# Factor     - dense det. time        : 0.00              GP order time          : 0.00
# Factor     - nonzeros before factor : 4095              after factor           : 4095
# Factor     - dense dim.             : 0                 flops                  : 4.16e+05
# ITE PFEAS    DFEAS    GFEAS    PRSTATUS   POBJ              DOBJ              MU       TIME
# 0   1.0e+00  1.0e+00  2.0e+00  0.00e+00   1.000000000e+00   0.000000000e+00   1.0e+00  0.08
# 1   0.0e+00  0.0e+00  0.0e+00  1.00e+00   0.000000000e+00   0.000000000e+00   0.0e+00  0.18
# Optimizer terminated. Time: 0.19
#
# 7786.044000000001 7786.044000000001 optimal
# [0 0 0 0 1 1] 12028.9918
# [0 0 0 0 1 1] 12028.9918
# [[91.4634 88.652 ]
#  [91.4634 89.9465]
#  [91.1834 89.0909]
#  [91.8788 90.0317]
#  [91.1772 90.343 ]
#  [89.7992 90.3987]
#  [90.3571 91.1116]
#  [92.0227 91.1382]
#  [91.9105 91.8114]
#  [91.141  91.9394]
#  [91.9571 91.4815]] [[ 84.2697  86.0997  92.7832 101.957 ]
#  [ 84.2697  85.1549  92.7607 102.651 ]
#  [ 84.0619  84.7458  93.4589 102.552 ]
#  [ 85.6542  84.601   93.3333 102.329 ]
#  [ 87.2093  84.4511  92.0536 102.516 ]
#  [ 87.1246  84.8366  90.3252 102.74  ]
#  [ 86.8726  84.4924  90.4617 102.74  ]
#  [ 86.7052  83.5455  91.4634 102.146 ]
#  [ 87.5899  83.3333  90.9669 101.683 ]
#  [ 89.1475  83.9661  89.7903 102.101 ]
#  [ 89.8204  84.9048  88.4148 102.114 ]]
# The problem has 6 noncommuting Hermitian variables
# Calculating block structure...
# Estimated number of SDP variables: 90
# Generating moment matrix...
# Reduced number of SDP variables: 90 90 (done: 101.11%, ETA 00:00:-0.0)
# Processing 166/462 constraints...
# Warning: The objective function has a non-zero 4000.5974000000006 constant term. It is not included in the SDP objective.
# Processing 462/462 constraints...
# Problem
#   Name                   :
#   Objective sense        : minimize
#   Type                   : CONIC (conic optimization problem)
#   Constraints            : 90
#   Affine conic cons.     : 0
#   Disjunctive cons.      : 0
#   Cones                  : 0
#   Scalar variables       : 0
#   Matrix variables       : 1 (scalarized: 113050)
#   Integer variables      : 0
#
# Optimizer started.
# Presolve started.
# Linear dependency checker started.
# Linear dependency checker terminated.
# Eliminator started.
# Freed constraints in eliminator : 0
# Eliminator terminated.
# Eliminator - tries                  : 1                 time                   : 0.00
# Lin. dep.  - tries                  : 1                 time                   : 0.00
# Lin. dep.  - primal attempts        : 1                 successes              : 1
# Lin. dep.  - dual attempts          : 0                 successes              : 0
# Lin. dep.  - primal deps.           : 0                 dual deps.             : 0
# Presolve terminated. Time: 0.00
# Optimizer  - threads                : 8
# Optimizer  - solved problem         : the primal
# Optimizer  - Constraints            : 90
# Optimizer  - Cones                  : 0
# Optimizer  - Scalar variables       : 0                 conic                  : 0
# Optimizer  - Semi-definite variables: 1                 scalarized             : 113050
# Factor     - setup time             : 0.00
# Factor     - dense det. time        : 0.00              GP order time          : 0.00
# Factor     - nonzeros before factor : 4095              after factor           : 4095
# Factor     - dense dim.             : 0                 flops                  : 3.60e+05
# ITE PFEAS    DFEAS    GFEAS    PRSTATUS   POBJ              DOBJ              MU       TIME
# 0   1.0e+00  1.0e+00  2.0e+00  0.00e+00   1.000000000e+00   0.000000000e+00   1.0e+00  0.03
# 1   0.0e+00  0.0e+00  0.0e+00  1.00e+00   0.000000000e+00   0.000000000e+00   0.0e+00  0.07
# Optimizer terminated. Time: 0.07
#
# 4000.5974000000006 4000.5974000000006 optimal
# The problem has 6 noncommuting Hermitian variables
# Calculating block structure...
# Estimated number of SDP variables: 90
# Generating moment matrix...
# Reduced number of SDP variables: 90 90 (done: 101.11%, ETA 00:00:-0.0)
# Processing 129/770 constraints...
# Warning: The objective function has a non-zero 8028.3944 constant term. It is not included in the SDP objective.
# Processing 770/770 constraints...
# Problem
#   Name                   :
#   Objective sense        : minimize
#   Type                   : CONIC (conic optimization problem)
#   Constraints            : 90
#   Affine conic cons.     : 0
#   Disjunctive cons.      : 0
#   Cones                  : 0
#   Scalar variables       : 0
#   Matrix variables       : 1 (scalarized: 306936)
#   Integer variables      : 0
#
# Optimizer started.
# Presolve started.
# Linear dependency checker started.
# Linear dependency checker terminated.
# Eliminator started.
# Freed constraints in eliminator : 0
# Eliminator terminated.
# Eliminator - tries                  : 1                 time                   : 0.00
# Lin. dep.  - tries                  : 1                 time                   : 0.00
# Lin. dep.  - primal attempts        : 1                 successes              : 1
# Lin. dep.  - dual attempts          : 0                 successes              : 0
# Lin. dep.  - primal deps.           : 0                 dual deps.             : 0
# Presolve terminated. Time: 0.00
# Optimizer  - threads                : 8
# Optimizer  - solved problem         : the primal
# Optimizer  - Constraints            : 90
# Optimizer  - Cones                  : 0
# Optimizer  - Scalar variables       : 0                 conic                  : 0
# Optimizer  - Semi-definite variables: 1                 scalarized             : 306936
# Factor     - setup time             : 0.00
# Factor     - dense det. time        : 0.00              GP order time          : 0.00
# Factor     - nonzeros before factor : 4095              after factor           : 4095
# Factor     - dense dim.             : 0                 flops                  : 4.16e+05
# ITE PFEAS    DFEAS    GFEAS    PRSTATUS   POBJ              DOBJ              MU       TIME
# 0   1.0e+00  1.0e+00  2.0e+00  0.00e+00   1.000000000e+00   0.000000000e+00   1.0e+00  0.08
# 1   0.0e+00  0.0e+00  0.0e+00  1.00e+00   0.000000000e+00   0.000000000e+00   0.0e+00  0.18
# Optimizer terminated. Time: 0.19
#
# 8028.3944 8028.3944 optimal
# [0 0 0 1 0 1] 12028.9918
# [[ 91.4634 101.957 ]
#  [ 91.4634 102.651 ]
#  [ 91.1834 102.552 ]
#  [ 91.8788 102.329 ]
#  [ 91.1772 102.516 ]
#  [ 89.7992 102.74  ]
#  [ 90.3571 102.74  ]
#  [ 92.0227 102.146 ]
#  [ 91.9105 101.683 ]
#  [ 91.141  102.101 ]
#  [ 91.9571 102.114 ]] [[84.2697 86.0997 92.7832 88.652 ]
#  [84.2697 85.1549 92.7607 89.9465]
#  [84.0619 84.7458 93.4589 89.0909]
#  [85.6542 84.601  93.3333 90.0317]
#  [87.2093 84.4511 92.0536 90.343 ]
#  [87.1246 84.8366 90.3252 90.3987]
#  [86.8726 84.4924 90.4617 91.1116]
#  [86.7052 83.5455 91.4634 91.1382]
#  [87.5899 83.3333 90.9669 91.8114]
#  [89.1475 83.9661 89.7903 91.9394]
#  [89.8204 84.9048 88.4148 91.4815]]
# The problem has 6 noncommuting Hermitian variables
# Calculating block structure...
# Estimated number of SDP variables: 90
# Generating moment matrix...
# Reduced number of SDP variables: 90 90 (done: 101.11%, ETA 00:00:-0.0)
# Processing 180/462 constraints...
# Warning: The objective function has a non-zero 4259.7656 constant term. It is not included in the SDP objective.
# Processing 462/462 constraints...
# Problem
#   Name                   :
#   Objective sense        : minimize
#   Type                   : CONIC (conic optimization problem)
#   Constraints            : 90
#   Affine conic cons.     : 0
#   Disjunctive cons.      : 0
#   Cones                  : 0
#   Scalar variables       : 0
#   Matrix variables       : 1 (scalarized: 113050)
#   Integer variables      : 0
#
# Optimizer started.
# Presolve started.
# Linear dependency checker started.
# Linear dependency checker terminated.
# Eliminator started.
# Freed constraints in eliminator : 0
# Eliminator terminated.
# Eliminator - tries                  : 1                 time                   : 0.00
# Lin. dep.  - tries                  : 1                 time                   : 0.00
# Lin. dep.  - primal attempts        : 1                 successes              : 1
# Lin. dep.  - dual attempts          : 0                 successes              : 0
# Lin. dep.  - primal deps.           : 0                 dual deps.             : 0
# Presolve terminated. Time: 0.00
# Optimizer  - threads                : 8
# Optimizer  - solved problem         : the primal
# Optimizer  - Constraints            : 90
# Optimizer  - Cones                  : 0
# Optimizer  - Scalar variables       : 0                 conic                  : 0
# Optimizer  - Semi-definite variables: 1                 scalarized             : 113050
# Factor     - setup time             : 0.00
# Factor     - dense det. time        : 0.00              GP order time          : 0.00
# Factor     - nonzeros before factor : 4095              after factor           : 4095
# Factor     - dense dim.             : 0                 flops                  : 3.60e+05
# ITE PFEAS    DFEAS    GFEAS    PRSTATUS   POBJ              DOBJ              MU       TIME
# 0   1.0e+00  1.0e+00  2.0e+00  0.00e+00   1.000000000e+00   0.000000000e+00   1.0e+00  0.03
# 1   0.0e+00  0.0e+00  0.0e+00  1.00e+00   0.000000000e+00   0.000000000e+00   0.0e+00  0.06
# Optimizer terminated. Time: 0.06
#
# 4259.7656 4259.7656 optimal
# The problem has 6 noncommuting Hermitian variables
# Calculating block structure...
# Estimated number of SDP variables: 90
# Generating moment matrix...
# Reduced number of SDP variables: 90 90 (done: 101.11%, ETA 00:00:-0.0)
# Processing 127/770 constraints...
# Warning: The objective function has a non-zero 7769.226200000001 constant term. It is not included in the SDP objective.
# Processing 770/770 constraints...
# Problem
#   Name                   :
#   Objective sense        : minimize
#   Type                   : CONIC (conic optimization problem)
#   Constraints            : 90
#   Affine conic cons.     : 0
#   Disjunctive cons.      : 0
#   Cones                  : 0
#   Scalar variables       : 0
#   Matrix variables       : 1 (scalarized: 306936)
#   Integer variables      : 0
#
# Optimizer started.
# Presolve started.
# Linear dependency checker started.
# Linear dependency checker terminated.
# Eliminator started.
# Freed constraints in eliminator : 0
# Eliminator terminated.
# Eliminator - tries                  : 1                 time                   : 0.00
# Lin. dep.  - tries                  : 1                 time                   : 0.00
# Lin. dep.  - primal attempts        : 1                 successes              : 1
# Lin. dep.  - dual attempts          : 0                 successes              : 0
# Lin. dep.  - primal deps.           : 0                 dual deps.             : 0
# Presolve terminated. Time: 0.00
# Optimizer  - threads                : 8
# Optimizer  - solved problem         : the primal
# Optimizer  - Constraints            : 90
# Optimizer  - Cones                  : 0
# Optimizer  - Scalar variables       : 0                 conic                  : 0
# Optimizer  - Semi-definite variables: 1                 scalarized             : 306936
# Factor     - setup time             : 0.00
# Factor     - dense det. time        : 0.00              GP order time          : 0.00
# Factor     - nonzeros before factor : 4095              after factor           : 4095
# Factor     - dense dim.             : 0                 flops                  : 4.16e+05
# ITE PFEAS    DFEAS    GFEAS    PRSTATUS   POBJ              DOBJ              MU       TIME
# 0   1.0e+00  1.0e+00  2.0e+00  0.00e+00   1.000000000e+00   0.000000000e+00   1.0e+00  0.09
# 1   0.0e+00  0.0e+00  0.0e+00  1.00e+00   0.000000000e+00   0.000000000e+00   0.0e+00  0.19
# Optimizer terminated. Time: 0.20
#
# 7769.226200000001 7769.226200000001 optimal
# [0 0 0 1 1 0] 12028.9918
# [[ 91.4634 101.957   88.652 ]
#  [ 91.4634 102.651   89.9465]
#  [ 91.1834 102.552   89.0909]
#  [ 91.8788 102.329   90.0317]
#  [ 91.1772 102.516   90.343 ]
#  [ 89.7992 102.74    90.3987]
#  [ 90.3571 102.74    91.1116]
#  [ 92.0227 102.146   91.1382]
#  [ 91.9105 101.683   91.8114]
#  [ 91.141  102.101   91.9394]
#  [ 91.9571 102.114   91.4815]] [[84.2697 86.0997 92.7832]
#  [84.2697 85.1549 92.7607]
#  [84.0619 84.7458 93.4589]
#  [85.6542 84.601  93.3333]
#  [87.2093 84.4511 92.0536]
#  [87.1246 84.8366 90.3252]
#  [86.8726 84.4924 90.4617]
#  [86.7052 83.5455 91.4634]
#  [87.5899 83.3333 90.9669]
#  [89.1475 83.9661 89.7903]
#  [89.8204 84.9048 88.4148]]
# The problem has 6 noncommuting Hermitian variables
# Calculating block structure...
# Estimated number of SDP variables: 90
# Generating moment matrix...
# Reduced number of SDP variables: 90 90 (done: 101.11%, ETA 00:00:-0.0)
# Processing 179/616 constraints...
# Warning: The objective function has a non-zero 6251.6554000000015 constant term. It is not included in the SDP objective.
# Processing 616/616 constraints...
# Problem
#   Name                   :
#   Objective sense        : minimize
#   Type                   : CONIC (conic optimization problem)
#   Constraints            : 90
#   Affine conic cons.     : 0
#   Disjunctive cons.      : 0
#   Cones                  : 0
#   Scalar variables       : 0
#   Matrix variables       : 1 (scalarized: 198135)
#   Integer variables      : 0
#
# Optimizer started.
# Presolve started.
# Linear dependency checker started.
# Linear dependency checker terminated.
# Eliminator started.
# Freed constraints in eliminator : 0
# Eliminator terminated.
# Eliminator - tries                  : 1                 time                   : 0.00
# Lin. dep.  - tries                  : 1                 time                   : 0.00
# Lin. dep.  - primal attempts        : 1                 successes              : 1
# Lin. dep.  - dual attempts          : 0                 successes              : 0
# Lin. dep.  - primal deps.           : 0                 dual deps.             : 0
# Presolve terminated. Time: 0.01
# Optimizer  - threads                : 8
# Optimizer  - solved problem         : the primal
# Optimizer  - Constraints            : 90
# Optimizer  - Cones                  : 0
# Optimizer  - Scalar variables       : 0                 conic                  : 0
# Optimizer  - Semi-definite variables: 1                 scalarized             : 198135
# Factor     - setup time             : 0.00
# Factor     - dense det. time        : 0.00              GP order time          : 0.00
# Factor     - nonzeros before factor : 4095              after factor           : 4095
# Factor     - dense dim.             : 0                 flops                  : 3.88e+05
# ITE PFEAS    DFEAS    GFEAS    PRSTATUS   POBJ              DOBJ              MU       TIME
# 0   1.0e+00  1.0e+00  2.0e+00  0.00e+00   1.000000000e+00   0.000000000e+00   1.0e+00  0.06
# 1   0.0e+00  0.0e+00  0.0e+00  1.00e+00   0.000000000e+00   0.000000000e+00   0.0e+00  0.12
# Optimizer terminated. Time: 0.13
#
# 6251.6554000000015 6251.6554000000015 optimal
# The problem has 6 noncommuting Hermitian variables
# Calculating block structure...
# Estimated number of SDP variables: 90
# Generating moment matrix...
# Reduced number of SDP variables: 90 90 (done: 101.11%, ETA 00:00:-0.0)
# Processing 163/616 constraints...
# Warning: The objective function has a non-zero 5777.3364 constant term. It is not included in the SDP objective.
# Processing 616/616 constraints...
# Problem
#   Name                   :
#   Objective sense        : minimize
#   Type                   : CONIC (conic optimization problem)
#   Constraints            : 90
#   Affine conic cons.     : 0
#   Disjunctive cons.      : 0
#   Cones                  : 0
#   Scalar variables       : 0
#   Matrix variables       : 1 (scalarized: 198135)
#   Integer variables      : 0
#
# Optimizer started.
# Presolve started.
# Linear dependency checker started.
# Linear dependency checker terminated.
# Eliminator started.
# Freed constraints in eliminator : 0
# Eliminator terminated.
# Eliminator - tries                  : 1                 time                   : 0.00
# Lin. dep.  - tries                  : 1                 time                   : 0.00
# Lin. dep.  - primal attempts        : 1                 successes              : 1
# Lin. dep.  - dual attempts          : 0                 successes              : 0
# Lin. dep.  - primal deps.           : 0                 dual deps.             : 0
# Presolve terminated. Time: 0.00
# Optimizer  - threads                : 8
# Optimizer  - solved problem         : the primal
# Optimizer  - Constraints            : 90
# Optimizer  - Cones                  : 0
# Optimizer  - Scalar variables       : 0                 conic                  : 0
# Optimizer  - Semi-definite variables: 1                 scalarized             : 198135
# Factor     - setup time             : 0.00
# Factor     - dense det. time        : 0.00              GP order time          : 0.00
# Factor     - nonzeros before factor : 4095              after factor           : 4095
# Factor     - dense dim.             : 0                 flops                  : 3.88e+05
# ITE PFEAS    DFEAS    GFEAS    PRSTATUS   POBJ              DOBJ              MU       TIME
# 0   1.0e+00  1.0e+00  2.0e+00  0.00e+00   1.000000000e+00   0.000000000e+00   1.0e+00  0.05
# 1   0.0e+00  0.0e+00  0.0e+00  1.00e+00   0.000000000e+00   0.000000000e+00   0.0e+00  0.11
# Optimizer terminated. Time: 0.12
#
# 5777.3364 5777.3364 optimal
# [0 0 0 1 1 1] 12028.991800000002
# [[92.7832 88.652 ]
#  [92.7607 89.9465]
#  [93.4589 89.0909]
#  [93.3333 90.0317]
#  [92.0536 90.343 ]
#  [90.3252 90.3987]
#  [90.4617 91.1116]
#  [91.4634 91.1382]
#  [90.9669 91.8114]
#  [89.7903 91.9394]
#  [88.4148 91.4815]] [[ 84.2697  86.0997  91.4634 101.957 ]
#  [ 84.2697  85.1549  91.4634 102.651 ]
#  [ 84.0619  84.7458  91.1834 102.552 ]
#  [ 85.6542  84.601   91.8788 102.329 ]
#  [ 87.2093  84.4511  91.1772 102.516 ]
#  [ 87.1246  84.8366  89.7992 102.74  ]
#  [ 86.8726  84.4924  90.3571 102.74  ]
#  [ 86.7052  83.5455  92.0227 102.146 ]
#  [ 87.5899  83.3333  91.9105 101.683 ]
#  [ 89.1475  83.9661  91.141  102.101 ]
#  [ 89.8204  84.9048  91.9571 102.114 ]]
# The problem has 6 noncommuting Hermitian variables
# Calculating block structure...
# Estimated number of SDP variables: 90
# Generating moment matrix...
# Reduced number of SDP variables: 90 90 (done: 101.11%, ETA 00:00:-0.0)
# Processing 160/462 constraints...
# Warning: The objective function has a non-zero 4003.5138000000006 constant term. It is not included in the SDP objective.
# Processing 462/462 constraints...
# Problem
#   Name                   :
#   Objective sense        : minimize
#   Type                   : CONIC (conic optimization problem)
#   Constraints            : 90
#   Affine conic cons.     : 0
#   Disjunctive cons.      : 0
#   Cones                  : 0
#   Scalar variables       : 0
#   Matrix variables       : 1 (scalarized: 113050)
#   Integer variables      : 0
#
# Optimizer started.
# Presolve started.
# Linear dependency checker started.
# Linear dependency checker terminated.
# Eliminator started.
# Freed constraints in eliminator : 0
# Eliminator terminated.
# Eliminator - tries                  : 1                 time                   : 0.00
# Lin. dep.  - tries                  : 1                 time                   : 0.00
# Lin. dep.  - primal attempts        : 1                 successes              : 1
# Lin. dep.  - dual attempts          : 0                 successes              : 0
# Lin. dep.  - primal deps.           : 0                 dual deps.             : 0
# Presolve terminated. Time: 0.00
# Optimizer  - threads                : 8
# Optimizer  - solved problem         : the primal
# Optimizer  - Constraints            : 90
# Optimizer  - Cones                  : 0
# Optimizer  - Scalar variables       : 0                 conic                  : 0
# Optimizer  - Semi-definite variables: 1                 scalarized             : 113050
# Factor     - setup time             : 0.00
# Factor     - dense det. time        : 0.00              GP order time          : 0.00
# Factor     - nonzeros before factor : 4095              after factor           : 4095
# Factor     - dense dim.             : 0                 flops                  : 3.60e+05
# ITE PFEAS    DFEAS    GFEAS    PRSTATUS   POBJ              DOBJ              MU       TIME
# 0   1.0e+00  1.0e+00  2.0e+00  0.00e+00   1.000000000e+00   0.000000000e+00   1.0e+00  0.03
# 1   0.0e+00  0.0e+00  0.0e+00  1.00e+00   0.000000000e+00   0.000000000e+00   0.0e+00  0.06
# Optimizer terminated. Time: 0.07
#
# 4003.5138000000006 4003.5138000000006 optimal
# The problem has 6 noncommuting Hermitian variables
# Calculating block structure...
# Estimated number of SDP variables: 90
# Generating moment matrix...
# Reduced number of SDP variables: 90 90 (done: 101.11%, ETA 00:00:-0.0)
# Processing 138/770 constraints...
# Warning: The objective function has a non-zero 8025.478 constant term. It is not included in the SDP objective.
# Processing 770/770 constraints...
# Problem
#   Name                   :
#   Objective sense        : minimize
#   Type                   : CONIC (conic optimization problem)
#   Constraints            : 90
#   Affine conic cons.     : 0
#   Disjunctive cons.      : 0
#   Cones                  : 0
#   Scalar variables       : 0
#   Matrix variables       : 1 (scalarized: 306936)
#   Integer variables      : 0
#
# Optimizer started.
# Presolve started.
# Linear dependency checker started.
# Linear dependency checker terminated.
# Eliminator started.
# Freed constraints in eliminator : 0
# Eliminator terminated.
# Eliminator - tries                  : 1                 time                   : 0.00
# Lin. dep.  - tries                  : 1                 time                   : 0.00
# Lin. dep.  - primal attempts        : 1                 successes              : 1
# Lin. dep.  - dual attempts          : 0                 successes              : 0
# Lin. dep.  - primal deps.           : 0                 dual deps.             : 0
# Presolve terminated. Time: 0.00
# Optimizer  - threads                : 8
# Optimizer  - solved problem         : the primal
# Optimizer  - Constraints            : 90
# Optimizer  - Cones                  : 0
# Optimizer  - Scalar variables       : 0                 conic                  : 0
# Optimizer  - Semi-definite variables: 1                 scalarized             : 306936
# Factor     - setup time             : 0.00
# Factor     - dense det. time        : 0.00              GP order time          : 0.00
# Factor     - nonzeros before factor : 4095              after factor           : 4095
# Factor     - dense dim.             : 0                 flops                  : 4.16e+05
# ITE PFEAS    DFEAS    GFEAS    PRSTATUS   POBJ              DOBJ              MU       TIME
# 0   1.0e+00  1.0e+00  2.0e+00  0.00e+00   1.000000000e+00   0.000000000e+00   1.0e+00  0.08
# 1   0.0e+00  0.0e+00  0.0e+00  1.00e+00   0.000000000e+00   0.000000000e+00   0.0e+00  0.18
# Optimizer terminated. Time: 0.19
#
# 8025.478 8025.478 optimal
# [0 0 1 0 0 1] 12028.9918
# [[ 92.7832 101.957 ]
#  [ 92.7607 102.651 ]
#  [ 93.4589 102.552 ]
#  [ 93.3333 102.329 ]
#  [ 92.0536 102.516 ]
#  [ 90.3252 102.74  ]
#  [ 90.4617 102.74  ]
#  [ 91.4634 102.146 ]
#  [ 90.9669 101.683 ]
#  [ 89.7903 102.101 ]
#  [ 88.4148 102.114 ]] [[84.2697 86.0997 91.4634 88.652 ]
#  [84.2697 85.1549 91.4634 89.9465]
#  [84.0619 84.7458 91.1834 89.0909]
#  [85.6542 84.601  91.8788 90.0317]
#  [87.2093 84.4511 91.1772 90.343 ]
#  [87.1246 84.8366 89.7992 90.3987]
#  [86.8726 84.4924 90.3571 91.1116]
#  [86.7052 83.5455 92.0227 91.1382]
#  [87.5899 83.3333 91.9105 91.8114]
#  [89.1475 83.9661 91.141  91.9394]
#  [89.8204 84.9048 91.9571 91.4815]]
# The problem has 6 noncommuting Hermitian variables
# Calculating block structure...
# Estimated number of SDP variables: 90
# Generating moment matrix...
# Reduced number of SDP variables: 90 90 (done: 101.11%, ETA 00:00:-0.0)
# Processing 181/462 constraints...
# Warning: The objective function has a non-zero 4262.682000000001 constant term. It is not included in the SDP objective.
# Processing 462/462 constraints...
# Problem
#   Name                   :
#   Objective sense        : minimize
#   Type                   : CONIC (conic optimization problem)
#   Constraints            : 90
#   Affine conic cons.     : 0
#   Disjunctive cons.      : 0
#   Cones                  : 0
#   Scalar variables       : 0
#   Matrix variables       : 1 (scalarized: 113050)
#   Integer variables      : 0
#
# Optimizer started.
# Presolve started.
# Linear dependency checker started.
# Linear dependency checker terminated.
# Eliminator started.
# Freed constraints in eliminator : 0
# Eliminator terminated.
# Eliminator - tries                  : 1                 time                   : 0.00
# Lin. dep.  - tries                  : 1                 time                   : 0.00
# Lin. dep.  - primal attempts        : 1                 successes              : 1
# Lin. dep.  - dual attempts          : 0                 successes              : 0
# Lin. dep.  - primal deps.           : 0                 dual deps.             : 0
# Presolve terminated. Time: 0.00
# Optimizer  - threads                : 8
# Optimizer  - solved problem         : the primal
# Optimizer  - Constraints            : 90
# Optimizer  - Cones                  : 0
# Optimizer  - Scalar variables       : 0                 conic                  : 0
# Optimizer  - Semi-definite variables: 1                 scalarized             : 113050
# Factor     - setup time             : 0.00
# Factor     - dense det. time        : 0.00              GP order time          : 0.00
# Factor     - nonzeros before factor : 4095              after factor           : 4095
# Factor     - dense dim.             : 0                 flops                  : 3.60e+05
# ITE PFEAS    DFEAS    GFEAS    PRSTATUS   POBJ              DOBJ              MU       TIME
# 0   1.0e+00  1.0e+00  2.0e+00  0.00e+00   1.000000000e+00   0.000000000e+00   1.0e+00  0.03
# 1   0.0e+00  0.0e+00  0.0e+00  1.00e+00   0.000000000e+00   0.000000000e+00   0.0e+00  0.06
# Optimizer terminated. Time: 0.07
#
# 4262.682000000001 4262.682000000001 optimal
# The problem has 6 noncommuting Hermitian variables
# Calculating block structure...
# Estimated number of SDP variables: 90
# Generating moment matrix...
# Reduced number of SDP variables: 90 90 (done: 101.11%, ETA 00:00:-0.0)
# Processing 120/770 constraints...
# Warning: The objective function has a non-zero 7766.309800000002 constant term. It is not included in the SDP objective.
# Processing 770/770 constraints...
# Problem
#   Name                   :
#   Objective sense        : minimize
#   Type                   : CONIC (conic optimization problem)
#   Constraints            : 90
#   Affine conic cons.     : 0
#   Disjunctive cons.      : 0
#   Cones                  : 0
#   Scalar variables       : 0
#   Matrix variables       : 1 (scalarized: 306936)
#   Integer variables      : 0
#
# Optimizer started.
# Presolve started.
# Linear dependency checker started.
# Linear dependency checker terminated.
# Eliminator started.
# Freed constraints in eliminator : 0
# Eliminator terminated.
# Eliminator - tries                  : 1                 time                   : 0.00
# Lin. dep.  - tries                  : 1                 time                   : 0.00
# Lin. dep.  - primal attempts        : 1                 successes              : 1
# Lin. dep.  - dual attempts          : 0                 successes              : 0
# Lin. dep.  - primal deps.           : 0                 dual deps.             : 0
# Presolve terminated. Time: 0.00
# Optimizer  - threads                : 8
# Optimizer  - solved problem         : the primal
# Optimizer  - Constraints            : 90
# Optimizer  - Cones                  : 0
# Optimizer  - Scalar variables       : 0                 conic                  : 0
# Optimizer  - Semi-definite variables: 1                 scalarized             : 306936
# Factor     - setup time             : 0.00
# Factor     - dense det. time        : 0.00              GP order time          : 0.00
# Factor     - nonzeros before factor : 4095              after factor           : 4095
# Factor     - dense dim.             : 0                 flops                  : 4.16e+05
# ITE PFEAS    DFEAS    GFEAS    PRSTATUS   POBJ              DOBJ              MU       TIME
# 0   1.0e+00  1.0e+00  2.0e+00  0.00e+00   1.000000000e+00   0.000000000e+00   1.0e+00  0.08
# 1   0.0e+00  0.0e+00  0.0e+00  1.00e+00   0.000000000e+00   0.000000000e+00   0.0e+00  0.18
# Optimizer terminated. Time: 0.18
#
# 7766.309800000002 7766.309800000002 optimal
# [0 0 1 0 1 0] 12028.991800000003
# [[ 92.7832 101.957   88.652 ]
#  [ 92.7607 102.651   89.9465]
#  [ 93.4589 102.552   89.0909]
#  [ 93.3333 102.329   90.0317]
#  [ 92.0536 102.516   90.343 ]
#  [ 90.3252 102.74    90.3987]
#  [ 90.4617 102.74    91.1116]
#  [ 91.4634 102.146   91.1382]
#  [ 90.9669 101.683   91.8114]
#  [ 89.7903 102.101   91.9394]
#  [ 88.4148 102.114   91.4815]] [[84.2697 86.0997 91.4634]
#  [84.2697 85.1549 91.4634]
#  [84.0619 84.7458 91.1834]
#  [85.6542 84.601  91.8788]
#  [87.2093 84.4511 91.1772]
#  [87.1246 84.8366 89.7992]
#  [86.8726 84.4924 90.3571]
#  [86.7052 83.5455 92.0227]
#  [87.5899 83.3333 91.9105]
#  [89.1475 83.9661 91.141 ]
#  [89.8204 84.9048 91.9571]]
# The problem has 6 noncommuting Hermitian variables
# Calculating block structure...
# Estimated number of SDP variables: 90
# Generating moment matrix...
# Reduced number of SDP variables: 90 90 (done: 101.11%, ETA 00:00:-0.0)
# Processing 181/616 constraints...
# Warning: The objective function has a non-zero 6254.571800000001 constant term. It is not included in the SDP objective.
# Processing 616/616 constraints...
# Problem
#   Name                   :
#   Objective sense        : minimize
#   Type                   : CONIC (conic optimization problem)
#   Constraints            : 90
#   Affine conic cons.     : 0
#   Disjunctive cons.      : 0
#   Cones                  : 0
#   Scalar variables       : 0
#   Matrix variables       : 1 (scalarized: 198135)
#   Integer variables      : 0
#
# Optimizer started.
# Presolve started.
# Linear dependency checker started.
# Linear dependency checker terminated.
# Eliminator started.
# Freed constraints in eliminator : 0
# Eliminator terminated.
# Eliminator - tries                  : 1                 time                   : 0.00
# Lin. dep.  - tries                  : 1                 time                   : 0.00
# Lin. dep.  - primal attempts        : 1                 successes              : 1
# Lin. dep.  - dual attempts          : 0                 successes              : 0
# Lin. dep.  - primal deps.           : 0                 dual deps.             : 0
# Presolve terminated. Time: 0.00
# Optimizer  - threads                : 8
# Optimizer  - solved problem         : the primal
# Optimizer  - Constraints            : 90
# Optimizer  - Cones                  : 0
# Optimizer  - Scalar variables       : 0                 conic                  : 0
# Optimizer  - Semi-definite variables: 1                 scalarized             : 198135
# Factor     - setup time             : 0.00
# Factor     - dense det. time        : 0.00              GP order time          : 0.00
# Factor     - nonzeros before factor : 4095              after factor           : 4095
# Factor     - dense dim.             : 0                 flops                  : 3.88e+05
# ITE PFEAS    DFEAS    GFEAS    PRSTATUS   POBJ              DOBJ              MU       TIME
# 0   1.0e+00  1.0e+00  2.0e+00  0.00e+00   1.000000000e+00   0.000000000e+00   1.0e+00  0.05
# 1   0.0e+00  0.0e+00  0.0e+00  1.00e+00   0.000000000e+00   0.000000000e+00   0.0e+00  0.10
# Optimizer terminated. Time: 0.11
#
# 6254.571800000001 6254.571800000001 optimal
# The problem has 6 noncommuting Hermitian variables
# Calculating block structure...
# Estimated number of SDP variables: 90
# Generating moment matrix...
# Reduced number of SDP variables: 90 90 (done: 101.11%, ETA 00:00:-0.0)
# Processing 152/616 constraints...
# Warning: The objective function has a non-zero 5774.42 constant term. It is not included in the SDP objective.
# Processing 616/616 constraints...
# Problem
#   Name                   :
#   Objective sense        : minimize
#   Type                   : CONIC (conic optimization problem)
#   Constraints            : 90
#   Affine conic cons.     : 0
#   Disjunctive cons.      : 0
#   Cones                  : 0
#   Scalar variables       : 0
#   Matrix variables       : 1 (scalarized: 198135)
#   Integer variables      : 0
#
# Optimizer started.
# Presolve started.
# Linear dependency checker started.
# Linear dependency checker terminated.
# Eliminator started.
# Freed constraints in eliminator : 0
# Eliminator terminated.
# Eliminator - tries                  : 1                 time                   : 0.00
# Lin. dep.  - tries                  : 1                 time                   : 0.00
# Lin. dep.  - primal attempts        : 1                 successes              : 1
# Lin. dep.  - dual attempts          : 0                 successes              : 0
# Lin. dep.  - primal deps.           : 0                 dual deps.             : 0
# Presolve terminated. Time: 0.00
# Optimizer  - threads                : 8
# Optimizer  - solved problem         : the primal
# Optimizer  - Constraints            : 90
# Optimizer  - Cones                  : 0
# ...
# Optimizer  - solved problem         : the primal
# Optimizer  - Constraints            : 90
# Optimizer  - Cones                  : 0
# Optimizer  - Scalar variables       : 0                 conic                  : 0
# Optimizer  - Semi-definite variables: 1                 scalarized             : 306936
# Factor     - setup time             : 0.00
# Factor     - dense det. time        : 0.00              GP order time          : 0.00
# Factor     - nonzeros before factor : 4095              after factor           : 4095
# Factor     - dense dim.             : 0                 flops                  : 4.16e+05
# ITE PFEAS    DFEAS    GFEAS    PRSTATUS   POBJ              DOBJ              MU       TIME
# 0   1.0e+00  1.0e+00  2.0e+00  0.00e+00   1.000000000e+00   0.000000000e+00   1.0e+00  0.10
# 1   0.0e+00  0.0e+00  0.0e+00  1.00e+00   0.000000000e+00   0.000000000e+00   0.0e+00  0.23
# Optimizer terminated. Time: 0.24
#
# 7769.226200000001 7769.226200000001 optimal
# The problem has 6 noncommuting Hermitian variables
# Calculating block structure...
# Estimated number of SDP variables: 90
# Generating moment matrix...
# Reduced number of SDP variables: 90 90 (done: 101.11%, ETA 00:00:-0.0)
# Processing 75/462 constraints...
# Warning: The objective function has a non-zero 4259.7656 constant term. It is not included in the SDP objective.
# Processing 462/462 constraints...
# Problem
#   Name                   :
#   Objective sense        : minimize
#   Type                   : CONIC (conic optimization problem)
#   Constraints            : 90
#   Affine conic cons.     : 0
#   Disjunctive cons.      : 0
#   Cones                  : 0
#   Scalar variables       : 0
#   Matrix variables       : 1 (scalarized: 113050)
#   Integer variables      : 0
#
# Optimizer started.
# Presolve started.
# Linear dependency checker started.
# Linear dependency checker terminated.
# Eliminator started.
# Freed constraints in eliminator : 0
# Eliminator terminated.
# Eliminator - tries                  : 1                 time                   : 0.00
# Lin. dep.  - tries                  : 1                 time                   : 0.00
# Lin. dep.  - primal attempts        : 1                 successes              : 1
# Lin. dep.  - dual attempts          : 0                 successes              : 0
# Lin. dep.  - primal deps.           : 0                 dual deps.             : 0
# Presolve terminated. Time: 0.00
# Optimizer  - threads                : 8
# Optimizer  - solved problem         : the primal
# Optimizer  - Constraints            : 90
# Optimizer  - Cones                  : 0
# Optimizer  - Scalar variables       : 0                 conic                  : 0
# Optimizer  - Semi-definite variables: 1                 scalarized             : 113050
# Factor     - setup time             : 0.00
# Factor     - dense det. time        : 0.00              GP order time          : 0.00
# Factor     - nonzeros before factor : 4095              after factor           : 4095
# Factor     - dense dim.             : 0                 flops                  : 3.60e+05
# ITE PFEAS    DFEAS    GFEAS    PRSTATUS   POBJ              DOBJ              MU       TIME
# 0   1.0e+00  1.0e+00  2.0e+00  0.00e+00   1.000000000e+00   0.000000000e+00   1.0e+00  0.04
# 1   0.0e+00  0.0e+00  0.0e+00  1.00e+00   0.000000000e+00   0.000000000e+00   0.0e+00  0.08
# Optimizer terminated. Time: 0.09
#
# 4259.7656 4259.7656 optimal
# [1 1 1 0 0 1] 12028.9918
# [[ 84.2697  86.0997  92.7832 101.957 ]
#  [ 84.2697  85.1549  92.7607 102.651 ]
#  [ 84.0619  84.7458  93.4589 102.552 ]
#  [ 85.6542  84.601   93.3333 102.329 ]
#  [ 87.2093  84.4511  92.0536 102.516 ]
#  [ 87.1246  84.8366  90.3252 102.74  ]
#  [ 86.8726  84.4924  90.4617 102.74  ]
#  [ 86.7052  83.5455  91.4634 102.146 ]
#  [ 87.5899  83.3333  90.9669 101.683 ]
#  [ 89.1475  83.9661  89.7903 102.101 ]
#  [ 89.8204  84.9048  88.4148 102.114 ]] [[91.4634 88.652 ]
#  [91.4634 89.9465]
#  [91.1834 89.0909]
#  [91.8788 90.0317]
#  [91.1772 90.343 ]
#  [89.7992 90.3987]
#  [90.3571 91.1116]
#  [92.0227 91.1382]
#  [91.9105 91.8114]
#  [91.141  91.9394]
#  [91.9571 91.4815]]
# The problem has 6 noncommuting Hermitian variables
# Calculating block structure...
# Estimated number of SDP variables: 90
# Generating moment matrix...
# Reduced number of SDP variables: 90 90 (done: 101.11%, ETA 00:00:-0.0)
# Processing 95/770 constraints...
# Warning: The objective function has a non-zero 8028.3944 constant term. It is not included in the SDP objective.
# Processing 770/770 constraints...
# Problem
#   Name                   :
#   Objective sense        : minimize
#   Type                   : CONIC (conic optimization problem)
#   Constraints            : 90
#   Affine conic cons.     : 0
#   Disjunctive cons.      : 0
#   Cones                  : 0
#   Scalar variables       : 0
#   Matrix variables       : 1 (scalarized: 306936)
#   Integer variables      : 0
#
# Optimizer started.
# Presolve started.
# Linear dependency checker started.
# Linear dependency checker terminated.
# Eliminator started.
# Freed constraints in eliminator : 0
# Eliminator terminated.
# Eliminator - tries                  : 1                 time                   : 0.00
# Lin. dep.  - tries                  : 1                 time                   : 0.00
# Lin. dep.  - primal attempts        : 1                 successes              : 1
# Lin. dep.  - dual attempts          : 0                 successes              : 0
# Lin. dep.  - primal deps.           : 0                 dual deps.             : 0
# Presolve terminated. Time: 0.00
# Optimizer  - threads                : 8
# Optimizer  - solved problem         : the primal
# Optimizer  - Constraints            : 90
# Optimizer  - Cones                  : 0
# Optimizer  - Scalar variables       : 0                 conic                  : 0
# Optimizer  - Semi-definite variables: 1                 scalarized             : 306936
# Factor     - setup time             : 0.00
# Factor     - dense det. time        : 0.00              GP order time          : 0.00
# Factor     - nonzeros before factor : 4095              after factor           : 4095
# Factor     - dense dim.             : 0                 flops                  : 4.16e+05
# ITE PFEAS    DFEAS    GFEAS    PRSTATUS   POBJ              DOBJ              MU       TIME
# 0   1.0e+00  1.0e+00  2.0e+00  0.00e+00   1.000000000e+00   0.000000000e+00   1.0e+00  0.09
# 1   0.0e+00  0.0e+00  0.0e+00  1.00e+00   0.000000000e+00   0.000000000e+00   0.0e+00  0.20
# Optimizer terminated. Time: 0.21
#
# 8028.3944 8028.3944 optimal
# The problem has 6 noncommuting Hermitian variables
# Calculating block structure...
# Estimated number of SDP variables: 90
# Generating moment matrix...
# Reduced number of SDP variables: 90 90 (done: 101.11%, ETA 00:00:-0.0)
# Processing 146/462 constraints...
# Warning: The objective function has a non-zero 4000.5974000000006 constant term. It is not included in the SDP objective.
# Processing 462/462 constraints...
# Problem
#   Name                   :
#   Objective sense        : minimize
#   Type                   : CONIC (conic optimization problem)
#   Constraints            : 90
#   Affine conic cons.     : 0
#   Disjunctive cons.      : 0
#   Cones                  : 0
#   Scalar variables       : 0
#   Matrix variables       : 1 (scalarized: 113050)
#   Integer variables      : 0
#
# Optimizer started.
# Presolve started.
# Linear dependency checker started.
# Linear dependency checker terminated.
# Eliminator started.
# Freed constraints in eliminator : 0
# Eliminator terminated.
# Eliminator - tries                  : 1                 time                   : 0.00
# Lin. dep.  - tries                  : 1                 time                   : 0.00
# Lin. dep.  - primal attempts        : 1                 successes              : 1
# Lin. dep.  - dual attempts          : 0                 successes              : 0
# Lin. dep.  - primal deps.           : 0                 dual deps.             : 0
# Presolve terminated. Time: 0.00
# Optimizer  - threads                : 8
# Optimizer  - solved problem         : the primal
# Optimizer  - Constraints            : 90
# Optimizer  - Cones                  : 0
# Optimizer  - Scalar variables       : 0                 conic                  : 0
# Optimizer  - Semi-definite variables: 1                 scalarized             : 113050
# Factor     - setup time             : 0.00
# Factor     - dense det. time        : 0.00              GP order time          : 0.00
# Factor     - nonzeros before factor : 4095              after factor           : 4095
# Factor     - dense dim.             : 0                 flops                  : 3.60e+05
# ITE PFEAS    DFEAS    GFEAS    PRSTATUS   POBJ              DOBJ              MU       TIME
# 0   1.0e+00  1.0e+00  2.0e+00  0.00e+00   1.000000000e+00   0.000000000e+00   1.0e+00  0.03
# 1   0.0e+00  0.0e+00  0.0e+00  1.00e+00   0.000000000e+00   0.000000000e+00   0.0e+00  0.06
# Optimizer terminated. Time: 0.06
#
# 4000.5974000000006 4000.5974000000006 optimal
# [1 1 1 0 1 0] 12028.9918
# [[84.2697 86.0997 92.7832 91.4634]
#  [84.2697 85.1549 92.7607 91.4634]
#  [84.0619 84.7458 93.4589 91.1834]
#  [85.6542 84.601  93.3333 91.8788]
#  [87.2093 84.4511 92.0536 91.1772]
#  [87.1246 84.8366 90.3252 89.7992]
#  [86.8726 84.4924 90.4617 90.3571]
#  [86.7052 83.5455 91.4634 92.0227]
#  [87.5899 83.3333 90.9669 91.9105]
#  [89.1475 83.9661 89.7903 91.141 ]
#  [89.8204 84.9048 88.4148 91.9571]] [[101.957   88.652 ]
#  [102.651   89.9465]
#  [102.552   89.0909]
#  [102.329   90.0317]
#  [102.516   90.343 ]
#  [102.74    90.3987]
#  [102.74    91.1116]
#  [102.146   91.1382]
#  [101.683   91.8114]
#  [102.101   91.9394]
#  [102.114   91.4815]]
# The problem has 6 noncommuting Hermitian variables
# Calculating block structure...
# Estimated number of SDP variables: 90
# Generating moment matrix...
# Reduced number of SDP variables: 90 90 (done: 101.11%, ETA 00:00:-0.0)
# Processing 121/770 constraints...
# Warning: The objective function has a non-zero 7786.044000000001 constant term. It is not included in the SDP objective.
# Processing 770/770 constraints...
# Problem
#   Name                   :
#   Objective sense        : minimize
#   Type                   : CONIC (conic optimization problem)
#   Constraints            : 90
#   Affine conic cons.     : 0
#   Disjunctive cons.      : 0
#   Cones                  : 0
#   Scalar variables       : 0
#   Matrix variables       : 1 (scalarized: 306936)
#   Integer variables      : 0
#
# Optimizer started.
# Presolve started.
# Linear dependency checker started.
# Linear dependency checker terminated.
# Eliminator started.
# Freed constraints in eliminator : 0
# Eliminator terminated.
# Eliminator - tries                  : 1                 time                   : 0.00
# Lin. dep.  - tries                  : 1                 time                   : 0.00
# Lin. dep.  - primal attempts        : 1                 successes              : 1
# Lin. dep.  - dual attempts          : 0                 successes              : 0
# Lin. dep.  - primal deps.           : 0                 dual deps.             : 0
# Presolve terminated. Time: 0.00
# Optimizer  - threads                : 8
# Optimizer  - solved problem         : the primal
# Optimizer  - Constraints            : 90
# Optimizer  - Cones                  : 0
# Optimizer  - Scalar variables       : 0                 conic                  : 0
# Optimizer  - Semi-definite variables: 1                 scalarized             : 306936
# Factor     - setup time             : 0.00
# Factor     - dense det. time        : 0.00              GP order time          : 0.00
# Factor     - nonzeros before factor : 4095              after factor           : 4095
# Factor     - dense dim.             : 0                 flops                  : 4.16e+05
# ITE PFEAS    DFEAS    GFEAS    PRSTATUS   POBJ              DOBJ              MU       TIME
# 0   1.0e+00  1.0e+00  2.0e+00  0.00e+00   1.000000000e+00   0.000000000e+00   1.0e+00  0.08
# 1   0.0e+00  0.0e+00  0.0e+00  1.00e+00   0.000000000e+00   0.000000000e+00   0.0e+00  0.19
# Optimizer terminated. Time: 0.20
#
# 7786.044000000001 7786.044000000001 optimal
# The problem has 6 noncommuting Hermitian variables
# Calculating block structure...
# Estimated number of SDP variables: 90
# Generating moment matrix...
# Reduced number of SDP variables: 90 90 (done: 101.11%, ETA 00:00:-0.0)
# Processing 151/462 constraints...
# Warning: The objective function has a non-zero 4242.9478 constant term. It is not included in the SDP objective.
# Processing 462/462 constraints...
# Problem
#   Name                   :
#   Objective sense        : minimize
#   Type                   : CONIC (conic optimization problem)
#   Constraints            : 90
#   Affine conic cons.     : 0
#   Disjunctive cons.      : 0
#   Cones                  : 0
#   Scalar variables       : 0
#   Matrix variables       : 1 (scalarized: 113050)
#   Integer variables      : 0
#
# Optimizer started.
# Presolve started.
# Linear dependency checker started.
# Linear dependency checker terminated.
# Eliminator started.
# Freed constraints in eliminator : 0
# Eliminator terminated.
# Eliminator - tries                  : 1                 time                   : 0.00
# Lin. dep.  - tries                  : 1                 time                   : 0.00
# Lin. dep.  - primal attempts        : 1                 successes              : 1
# Lin. dep.  - dual attempts          : 0                 successes              : 0
# Lin. dep.  - primal deps.           : 0                 dual deps.             : 0
# Presolve terminated. Time: 0.00
# Optimizer  - threads                : 8
# Optimizer  - solved problem         : the primal
# Optimizer  - Constraints            : 90
# Optimizer  - Cones                  : 0
# Optimizer  - Scalar variables       : 0                 conic                  : 0
# Optimizer  - Semi-definite variables: 1                 scalarized             : 113050
# Factor     - setup time             : 0.00
# Factor     - dense det. time        : 0.00              GP order time          : 0.00
# Factor     - nonzeros before factor : 4095              after factor           : 4095
# Factor     - dense dim.             : 0                 flops                  : 3.60e+05
# ITE PFEAS    DFEAS    GFEAS    PRSTATUS   POBJ              DOBJ              MU       TIME
# 0   1.0e+00  1.0e+00  2.0e+00  0.00e+00   1.000000000e+00   0.000000000e+00   1.0e+00  0.03
# 1   0.0e+00  0.0e+00  0.0e+00  1.00e+00   0.000000000e+00   0.000000000e+00   0.0e+00  0.08
# Optimizer terminated. Time: 0.08
#
# 4242.9478 4242.9478 optimal
# [1 1 1 1 0 0] 12028.9918
# [0 0 0 0 1 1]

# %% [markdown]
# # F1 score

# %%
labels_pred = L
labels_true01 = [0,0,0,1,1,1]
labels_true10 = [1,1,1,0,0,0]
print(max(f1_score(labels_true01, labels_pred, average='weighted'),f1_score(labels_true10, labels_pred, average='weighted')))
# Out:
# 0.8285714285714286

# %% [markdown]
# # Fowlkes-Mallows Scores(FMI)

# %%
from sklearn import metrics
labels_true = [0,0,0,1,1,1]
metrics.fowlkes_mallows_score(labels_true, labels_pred)
# Out:
# 0.6172133998483675

# %% [markdown]
# # Silhouette Coefficient

# %%
import numpy as np
labels_true = [0,0,0,1,1,1]
metrics.silhouette_score(np.array(labels_true).reshape(-1, 1), np.array(labels_pred).reshape(-1, 1), metric='euclidean')
# Out:
# /Users/xiaoyuhe/anaconda3/lib/python3.10/site-packages/sklearn/utils/validation.py:1184: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# 0.5
